# %% [markdown]
# # **USA House Sales Price Prediction (May 2014 – May 2015)**

# %% [markdown]
# ## **Import the required libraries**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.pipeline import Pipeline
# %matplotlib inline

# %% [markdown]
# # Importing Data Sets

# %%
URL='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/FinalModule_Coursera/data/kc_house_data_NaN.csv'

# %%
df = pd.read_csv(URL)
df.head()
# Out:
#    Unnamed: 0          id             date     price  bedrooms  bathrooms  \
# 0           0  7129300520  20141013T000000  221900.0       3.0       1.00
# 1           1  6414100192  20141209T000000  538000.0       3.0       2.25
# 2           2  5631500400  20150225T000000  180000.0       2.0       1.00
# 3           3  2487200875  20141209T000000  604000.0       4.0       3.00
# 4           4  1954400510  20150218T000000  510000.0       3.0       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 0         1180      5650     1.0           0  ...      7        1180
# 1         2570      7242     2.0           0  ...      7        2170
# 2          770     10000     1.0           0  ...      6         770
# 3         1960      5000     1.0           0  ...      7        1050
# 4         1680      8080     1.0           0  ...      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0              0      1955             0    98178  47.5112 -122.257
# 1            400      1951          1991    98125  47.7210 -122.319
# 2              0      1933             0    98028  47.7379 -122.233
# 3            910      1965             0    98136  47.5208 -122.393
# 4              0      1987             0    98074  47.6168 -122.045
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
# 1           1690        7639
# 2           2720        8062
# 3           1360        5000
# 4           1800        7503
#
# [5 rows x 22 columns]

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# First we drop Unnamed: 0 and id Column from our DataFrame
# Beacuse we dont need them for our further analysis.

# %%
df.drop(columns=['Unnamed: 0','id'],inplace=True)
df.head()
# Out:
#               date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  20141013T000000  221900.0       3.0       1.00         1180      5650
# 1  20141209T000000  538000.0       3.0       2.25         2570      7242
# 2  20150225T000000  180000.0       2.0       1.00          770     10000
# 3  20141209T000000  604000.0       4.0       3.00         1960      5000
# 4  20150218T000000  510000.0       3.0       2.00         1680      8080
#
#    floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0     1.0           0     0          3      7        1180              0
# 1     2.0           0     0          3      7        2170            400
# 2     1.0           0     0          3      6         770              0
# 3     1.0           0     0          5      7        1050            910
# 4     1.0           0     0          3      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503

# %% [markdown]
# Check for Missing values

# %%
df.isnull().sum()
# Out:
# date              0
# price             0
# bedrooms         13
# bathrooms        10
# sqft_living       0
# sqft_lot          0
# floors            0
# waterfront        0
# view              0
# condition         0
# grade             0
# sqft_above        0
# sqft_basement     0
# yr_built          0
# yr_renovated      0
# zipcode           0
# lat               0
# long              0
# sqft_living15     0
# sqft_lot15        0
# dtype: int64

# %% [markdown]
# We can see we have missing values for the columns 'bedrooms'and bathrooms 13 and 10 respectively

# %%
df[['bedrooms','bathrooms']].dtypes
# Out:
# bedrooms     float64
# bathrooms    float64
# dtype: object

# %% [markdown]
# As we see both columns contain numeric values and thier dtype is float.
#
# So we can calculate their mean and replace it with missing values.

# %%
for col in df[['bedrooms','bathrooms']]:
    df[col]=df[col].replace(np.nan,df[col].mean())

df.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.372870      2.115736   2079.899736  1.510697e+04
# std    3.671272e+05      0.926378      0.768818    918.440897  4.142051e+04
# min    7.500000e+04      1.000000      0.500000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       1.494309      0.007542      0.234303      3.409430      7.656873
# std        0.539989      0.086517      0.766318      0.650743      1.175459
# min        1.000000      0.000000      0.000000      1.000000      1.000000
# 25%        1.000000      0.000000      0.000000      3.000000      7.000000
# 50%        1.500000      0.000000      0.000000      3.000000      7.000000
# 75%        2.000000      0.000000      0.000000      4.000000      8.000000
# max        3.500000      1.000000      4.000000      5.000000     13.000000
#
#          sqft_above  sqft_basement      yr_built  yr_renovated       zipcode  \
# count  21613.000000   21613.000000  21613.000000  21613.000000  21613.000000
# mean    1788.390691     291.509045   1971.005136     84.402258  98077.939805
# std      828.090978     442.575043     29.373411    401.679240     53.505026
# min      290.000000       0.000000   1900.000000      0.000000  98001.000000
# 25%     1190.000000       0.000000   1951.000000      0.000000  98033.000000
# 50%     1560.000000       0.000000   1975.000000      0.000000  98065.000000
# 75%     2210.000000     560.000000   1997.000000      0.000000  98118.000000
# max     9410.000000    4820.000000   2015.000000   2015.000000  98199.000000
#
#                 lat          long  sqft_living15     sqft_lot15
# count  21613.000000  21613.000000   21613.000000   21613.000000
# mean      47.560053   -122.213896    1986.552492   12768.455652
# std        0.138564      0.140828     685.391304   27304.179631
# min       47.155900   -122.519000     399.000000     651.000000
# 25%       47.471000   -122.328000    1490.000000    5100.000000
# 50%       47.571800   -122.230000    1840.000000    7620.000000
# 75%       47.678000   -122.125000    2360.000000   10083.000000
# max       47.777600   -121.315000    6210.000000  871200.000000

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# Check for the dtype of columns

# %%
df.dtypes
# Out:
# date              object
# price            float64
# bedrooms         float64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
for col in df[['bedrooms','bathrooms','floors','waterfront']]:
    print(df[col].value_counts())
# Out:
# bedrooms
# 3.00000     9824
# 4.00000     6882
# 2.00000     2760
# 5.00000     1601
# 6.00000      272
# 1.00000      199
# 7.00000       38
# 3.37287       13
# 8.00000       13
# 9.00000        6
# 10.00000       3
# 11.00000       1
# 33.00000       1
# Name: count, dtype: int64
# bathrooms
# 2.500000    5380
# 1.000000    3852
# 1.750000    3048
# 2.250000    2047
# 2.000000    1930
# 1.500000    1446
# 2.750000    1185
# 3.000000     753
# 3.500000     731
# 3.250000     589
# 3.750000     155
# 4.000000     136
# 4.500000     100
# 4.250000      79
# 0.750000      72
# 4.750000      23
# 5.000000      21
# 5.250000      13
# 2.115736      10
# 5.500000      10
# 1.250000       9
# 6.000000       6
# 0.500000       4
# 5.750000       4
# 6.750000       2
# 8.000000       2
# 6.500000       2
# 6.250000       2
# 7.750000       1
# 7.500000       1
# Name: count, dtype: int64
# floors
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: count, dtype: int64
# waterfront
# 0    21450
# 1      163
# Name: count, dtype: int64

# %% [markdown]
# We visualy check floors and waterfront columns with price

# %%
sns.barplot(x='floors',y='price',data=df)
# Out:
# <Axes: xlabel='floors', ylabel='price'>

# %%
sns.barplot(x='waterfront',y='price',data=df)
# Out:
# <Axes: xlabel='waterfront', ylabel='price'>

# %%
numeric_data=df.select_dtypes(include=[int,float])
numeric_data.corr()
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.308797   0.525738     0.702035  0.089661  0.256794
# bedrooms       0.308797  1.000000   0.514194     0.578077  0.032307  0.178022
# bathrooms      0.525738  0.514194   1.000000     0.755371  0.087929  0.502132
# sqft_living    0.702035  0.578077   0.755371     1.000000  0.172826  0.353949
# sqft_lot       0.089661  0.032307   0.087929     0.172826  1.000000 -0.005201
# floors         0.256794  0.178022   0.502132     0.353949 -0.005201  1.000000
# waterfront     0.266369 -0.006800   0.063744     0.103818  0.021604  0.023698
# view           0.397293  0.080058   0.188341     0.284611  0.074710  0.029444
# condition      0.036362  0.026690  -0.126197    -0.058753 -0.008958 -0.263768
# grade          0.667434  0.356589   0.664676     0.762704  0.113621  0.458183
# sqft_above     0.605567  0.479286   0.686309     0.876597  0.183512  0.523885
# sqft_basement  0.323816  0.302856   0.283428     0.435043  0.015286 -0.245705
# yr_built       0.054012  0.155749   0.506913     0.318049  0.053080  0.489319
# yr_renovated   0.126434  0.018456   0.050560     0.055363  0.007644  0.006338
# zipcode       -0.053203 -0.153736  -0.204819    -0.199430 -0.129574 -0.059121
# lat            0.307003 -0.009735   0.024246     0.052529 -0.085683  0.049614
# long           0.021626  0.130978   0.224922     0.240223  0.229521  0.125419
# sqft_living15  0.585379  0.393356   0.569467     0.756420  0.144608  0.279885
# sqft_lot15     0.082447  0.030430   0.087539     0.183286  0.718557 -0.011269
#
#                waterfront      view  condition     grade  sqft_above  \
# price            0.266369  0.397293   0.036362  0.667434    0.605567
# bedrooms        -0.006800  0.080058   0.026690  0.356589    0.479286
# bathrooms        0.063744  0.188341  -0.126197  0.664676    0.686309
# sqft_living      0.103818  0.284611  -0.058753  0.762704    0.876597
# sqft_lot         0.021604  0.074710  -0.008958  0.113621    0.183512
# floors           0.023698  0.029444  -0.263768  0.458183    0.523885
# waterfront       1.000000  0.401857   0.016653  0.082775    0.072075
# view             0.401857  1.000000   0.045990  0.251321    0.167649
# condition        0.016653  0.045990   1.000000 -0.144674   -0.158214
# grade            0.082775  0.251321  -0.144674  1.000000    0.755923
# sqft_above       0.072075  0.167649  -0.158214  0.755923    1.000000
# sqft_basement    0.080588  0.276947   0.174105  0.168392   -0.051943
# yr_built        -0.026161 -0.053440  -0.361417  0.446963    0.423898
# yr_renovated     0.092885  0.103917  -0.060618  0.014414    0.023285
# zipcode          0.030285  0.084827   0.003026 -0.184862   -0.261190
# lat             -0.014274  0.006157  -0.014941  0.114084   -0.000816
# long            -0.041910 -0.078400  -0.106500  0.198372    0.343803
# sqft_living15    0.086463  0.280439  -0.092824  0.713202    0.731870
# sqft_lot15       0.030703  0.072575  -0.003406  0.119248    0.194050
#
#                sqft_basement  yr_built  yr_renovated   zipcode       lat  \
# price               0.323816  0.054012      0.126434 -0.053203  0.307003
# bedrooms            0.302856  0.155749      0.018456 -0.153736 -0.009735
# bathrooms           0.283428  0.506913      0.050560 -0.204819  0.024246
# sqft_living         0.435043  0.318049      0.055363 -0.199430  0.052529
# sqft_lot            0.015286  0.053080      0.007644 -0.129574 -0.085683
# floors             -0.245705  0.489319      0.006338 -0.059121  0.049614
# waterfront          0.080588 -0.026161      0.092885  0.030285 -0.014274
# view                0.276947 -0.053440      0.103917  0.084827  0.006157
# condition           0.174105 -0.361417     -0.060618  0.003026 -0.014941
# grade               0.168392  0.446963      0.014414 -0.184862  0.114084
# sqft_above         -0.051943  0.423898      0.023285 -0.261190 -0.000816
# sqft_basement       1.000000 -0.133124      0.071323  0.074845  0.110538
# yr_built           -0.133124  1.000000     -0.224874 -0.346869 -0.148122
# yr_renovated        0.071323 -0.224874      1.000000  0.064357  0.029398
# zipcode             0.074845 -0.346869      0.064357  1.000000  0.267048
# lat                 0.110538 -0.148122      0.029398  0.267048  1.000000
# long               -0.144765  0.409356     -0.068372 -0.564072 -0.135512
# sqft_living15       0.200355  0.326229     -0.002673 -0.279033  0.048858
# sqft_lot15          0.017276  0.070958      0.007854 -0.147221 -0.086419
#
#                    long  sqft_living15  sqft_lot15
# price          0.021626       0.585379    0.082447
# bedrooms       0.130978       0.393356    0.030430
# bathrooms      0.224922       0.569467    0.087539
# sqft_living    0.240223       0.756420    0.183286
# sqft_lot       0.229521       0.144608    0.718557
# floors         0.125419       0.279885   -0.011269
# waterfront    -0.041910       0.086463    0.030703
# view          -0.078400       0.280439    0.072575
# condition     -0.106500      -0.092824   -0.003406
# grade          0.198372       0.713202    0.119248
# sqft_above     0.343803       0.731870    0.194050
# sqft_basement -0.144765       0.200355    0.017276
# yr_built       0.409356       0.326229    0.070958
# yr_renovated  -0.068372      -0.002673    0.007854
# zipcode       -0.564072      -0.279033   -0.147221
# lat           -0.135512       0.048858   -0.086419
# long           1.000000       0.334605    0.254451
# sqft_living15  0.334605       1.000000    0.183192
# sqft_lot15     0.254451       0.183192    1.000000

# %%
#Enter Your Code, Execute and take the Screenshot
sns.regplot(x="sqft_above",y="price",data=df)
plt.ylim(0,)
# Out:
# (0.0, 8081250.0)

# %%
for col in numeric_data.columns:
  plt.figure(figsize=(8,4))
  sns.regplot(x=col,y='price',data=numeric_data)
  plt.ylim(0,)
  plt.xlabel(col)
  plt.ylabel('Price')
  plt.title(f'Relation of {col} vs Price' )

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
for col in numeric_data[['floors','waterfront', 'view', 'condition', 'grade']]:
  plt.figure(figsize=(8,6))
  sns.barplot(x=col,y='price',data=numeric_data)

# %%
from scipy import stats

# %%
for col in numeric_data.columns:
  pearson_coef,p_value=stats.pearsonr(df[col],df['price'])
  #print(f'{col}   pearson_coef    ',pearson_coef,'       with p_value     ',p_value)
  print(f"{col:<20} | Pearson Coef: {pearson_coef:<10.4f} | p-value: {p_value:<10.4f}")
# Out:
# price                | Pearson Coef: 1.0000     | p-value: 0.0000
# bedrooms             | Pearson Coef: 0.3088     | p-value: 0.0000
# bathrooms            | Pearson Coef: 0.5257     | p-value: 0.0000
# sqft_living          | Pearson Coef: 0.7020     | p-value: 0.0000
# sqft_lot             | Pearson Coef: 0.0897     | p-value: 0.0000
# floors               | Pearson Coef: 0.2568     | p-value: 0.0000
# waterfront           | Pearson Coef: 0.2664     | p-value: 0.0000
# view                 | Pearson Coef: 0.3973     | p-value: 0.0000
# condition            | Pearson Coef: 0.0364     | p-value: 0.0000
# grade                | Pearson Coef: 0.6674     | p-value: 0.0000
# sqft_above           | Pearson Coef: 0.6056     | p-value: 0.0000
# sqft_basement        | Pearson Coef: 0.3238     | p-value: 0.0000
# yr_built             | Pearson Coef: 0.0540     | p-value: 0.0000
# yr_renovated         | Pearson Coef: 0.1264     | p-value: 0.0000
# zipcode              | Pearson Coef: -0.0532    | p-value: 0.0000
# lat                  | Pearson Coef: 0.3070     | p-value: 0.0000
# long                 | Pearson Coef: 0.0216     | p-value: 0.0015
# sqft_living15        | Pearson Coef: 0.5854     | p-value: 0.0000
# sqft_lot15           | Pearson Coef: 0.0824     | p-value: 0.0000

# %% [markdown]
# # Model Development

# %% [markdown]
# From above analysis we find below features are good predictors of price.

# %%
features =["floors", "waterfront","bedrooms" ,"sqft_basement" ,"lat","view" ,"bathrooms","sqft_living15","sqft_above","grade","sqft_living"]

# %%
x=df[features]
y=df['price']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score
from xgboost import XGBRegressor

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
linear=LinearRegression()
ridge=Ridge()
lasso=Lasso()
random=RandomForestRegressor(n_estimators=100,random_state=42)
decision=DecisionTreeRegressor()
xgb=XGBRegressor(n_estimators=100,random_state=42)

# %%
linear.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
ridge.fit(x_train,y_train)
# Out:
# Ridge()

# %%
random.fit(x_train,y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
decision.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
xgb.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=100,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
print("Train Score:")
print("LinearRegression:",linear.score(x_train,y_train))
print("Ridge:",ridge.score(x_train,y_train))
print("RandomForestRegressor:",random.score(x_train,y_train))
print("DecisionTreeRegressor:",decision.score(x_train,y_train))
print("DecisionTreeRegressor:",xgb.score(x_train,y_train))
# Out:
# Train Score:
# LinearRegression: 0.6564450189198039
# Ridge: 0.6564429442735157
# RandomForestRegressor: 0.9738487160025543
# DecisionTreeRegressor: 0.9992247658840684
# DecisionTreeRegressor: 0.9435179059418384

# %%
print("Test Score:")
print("LinearRegression:",linear.score(x_test,y_test))
print("Ridge:",ridge.score(x_test,y_test))
print("RandomForestRegressor:",random.score(x_test,y_test))
print("DecisionTreeRegressor:",decision.score(x_test,y_test))
print("xgb:",xgb.score(x_test,y_test))
# Out:
# Test Score:
# LinearRegression: 0.6614029431732619
# Ridge: 0.6613549872405993
# RandomForestRegressor: 0.7822214825579044
# DecisionTreeRegressor: 0.5916369959120135
# xgb: 0.7132001951552925

# %%
print("Test R score:")
print("LinearRegression:",r2_score(y_test,linear.predict(x_test)))
print("Ridge:",r2_score(y_test,ridge.predict(x_test)))
print("RandomForestRegressor:",r2_score(y_test,random.predict(x_test)))
print("DecisionTreeRegressor:",r2_score(y_test,decision.predict(x_test)))
print("xgb:",r2_score(y_test,xgb.predict(x_test)))
# Out:
# Test R score:
# LinearRegression: 0.6614029431732619
# Ridge: 0.6613549872405993
# RandomForestRegressor: 0.7822214825579044
# DecisionTreeRegressor: 0.5916369959120135
# xgb: 0.7132001951552925

# %% [markdown]
# # Model Evaluation and Refinement

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(LinearRegression(), x_train, y_train, cv=5, scoring='r2')
print("Cross-validated R² scores:", scores)
print("Average R²:", scores.mean())
# Out:
# Cross-validated R² scores: [0.63736797 0.64090679 0.67660985 0.67558063 0.64720931]
# Average R²: 0.655534911523831

# %%
scores = cross_val_score(Ridge(), x_train, y_train, cv=5, scoring='r2')
print("Cross-validated R² scores:", scores)
print("Average R²:", scores.mean())
# Out:
# Cross-validated R² scores: [0.6372845  0.64098427 0.67660472 0.67555912 0.64724473]
# Average R²: 0.6555354688206317

# %%
scores = cross_val_score(RandomForestRegressor(), x_train, y_train, cv=5, scoring='r2')
print("Cross-validated R² scores:", scores)
print("Average R²:", scores.mean())
# Out:
# Cross-validated R² scores: [0.81056791 0.82010821 0.82062794 0.82480876 0.80257023]
# Average R²: 0.8157366112960771

# %%
scores = cross_val_score(DecisionTreeRegressor(), x_train, y_train, cv=5, scoring='r2')
print("Cross-validated R² scores:", scores)
print("Average R²:", scores.mean())
# Out:
# Cross-validated R² scores: [0.62247725 0.65244243 0.64836635 0.64879587 0.57775453]
# Average R²: 0.6299672863285288

# %%
scores = cross_val_score(XGBRegressor(), x_train, y_train, cv=5, scoring='r2')
print("Cross-validated R² scores:", scores)
print("Average R²:", scores.mean())
# Out:
# Cross-validated R² scores: [0.79789264 0.83470664 0.82135074 0.83794204 0.78078115]
# Average R²: 0.8145346429243843

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'n_estimators': [200,300],
    'max_depth': [20,30],
}

# %%
grid_search=GridSearchCV(estimator=RandomForestRegressor(),param_grid=param_grid,cv=5,scoring='r2',verbose=2)
grid_search.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV] END .....................max_depth=20, n_estimators=200; total time=  25.3s
# [CV] END .....................max_depth=20, n_estimators=200; total time=  25.2s
# [CV] END .....................max_depth=20, n_estimators=200; total time=  25.3s
# [CV] END .....................max_depth=20, n_estimators=200; total time=  25.3s
# [CV] END .....................max_depth=20, n_estimators=200; total time=  25.1s
# [CV] END .....................max_depth=20, n_estimators=300; total time=  37.6s
# [CV] END .....................max_depth=20, n_estimators=300; total time=  37.2s
# [CV] END .....................max_depth=20, n_estimators=300; total time=  36.8s
# [CV] END .....................max_depth=20, n_estimators=300; total time=  37.5s
# [CV] END .....................max_depth=20, n_estimators=300; total time=  37.5s
# [CV] END .....................max_depth=30, n_estimators=200; total time=  26.5s
# [CV] END .....................max_depth=30, n_estimators=200; total time=  26.5s
# [CV] END .....................max_depth=30, n_estimators=200; total time=  26.5s
# [CV] END .....................max_depth=30, n_estimators=200; total time=  26.8s
# [CV] END .....................max_depth=30, n_estimators=200; total time=  26.7s
# [CV] END .....................max_depth=30, n_estimators=300; total time=  39.9s
# [CV] END .....................max_depth=30, n_estimators=300; total time=  39.9s
# [CV] END .....................max_depth=30, n_estimators=300; total time=  40.2s
# [CV] END .....................max_depth=30, n_estimators=300; total time=  40.2s
# [CV] END .....................max_depth=30, n_estimators=300; total time=  40.1s
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [20, 30], 'n_estimators': [200, 300]},
#              scoring='r2', verbose=2)

# %%
print("Best Parameters:", grid_search.best_params_)
# Out:
# Best Parameters: {'max_depth': 30, 'n_estimators': 300}

# %%
best_model = grid_search.best_estimator_
best_model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=30, n_estimators=300)

# %%
from sklearn.metrics import mean_squared_error, r2_score

y_pred = best_model.predict(x_test)
print("Test MSE:", mean_squared_error(y_test, y_pred))
print("Test R² Score:", r2_score(y_test, y_pred))
# Out:
# Test MSE: 32778710903.112423
# Test R² Score: 0.7831761888866865

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
pipline=Pipeline([('scalar',StandardScaler()),('regressor',RandomForestRegressor(max_depth=20, n_estimators=200))])
pipline.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('scalar', StandardScaler()),
#                 ('regressor',
#                  RandomForestRegressor(max_depth=20, n_estimators=200))])

# %%
pipline.score(x_test,y_test)
y_pred_pip=pipline.predict(x_test)
print("Test MSE:", mean_squared_error(y_test, y_pred_pip))
print("Test R² Score:", r2_score(y_test, y_pred_pip))
# Out:
# Test MSE: 33800415323.825123
# Test R² Score: 0.7764178436001665

# %%
import joblib
joblib.dump(pipline,"USA_House_Price_Prediction_model.pkl")
# Out:
# ['USA_House_Price_Prediction_model.pkl']
